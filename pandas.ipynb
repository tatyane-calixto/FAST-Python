# %% [markdown]
# <a href="https://colab.research.google.com/github/tatyane-calixto/FAST-Python/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df_vacinados = pd.read_csv('vacinados.csv')
df_vacinados = df_vacinados.sort_values('data_vacinacao',ascending=False)
df_vacinados.head(10)
# Out:
#      _id  faixa_etaria  idade       sexo raca_cor municipio  \
# 638  639  70 a 74 anos     73   FEMININO   BRANCA    RECIFE
# 413  414  20 a 24 anos     24   FEMININO   BRANCA    RECIFE
# 162  163  25 a 29 anos     25   FEMININO    PARDA    RECIFE
# 496  497  20 a 24 anos     24   FEMININO    PARDA    RECIFE
# 406  407  25 a 29 anos     25  MASCULINO   BRANCA    RECIFE
# 99   100  15 a 19 anos     18  MASCULINO    PRETA    RECIFE
# 225  226  25 a 29 anos     26  MASCULINO    PARDA    RECIFE
# 443  444  25 a 29 anos     25  MASCULINO    PARDA    RECIFE
# 482  483  25 a 29 anos     25   FEMININO    PARDA    RECIFE
# 67    68  25 a 29 anos     25  MASCULINO   BRANCA    RECIFE
#
#                                grupo  \
# 638                           IDOSOS
# 413        TRABALHADORES DA EDUCAÇÃO
# 162           TRABALHADORES DA SAÚDE
# 496           TRABALHADORES DA SAÚDE
# 406         PESSOAS COM COMORBIDADES
# 99   PÚBLICO EM GERAL (18 a 59 anos)
# ...
